# %% [markdown]
# <a href="https://colab.research.google.com/github/yihimin/mbti_test/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1. 데이터 수집

# %% [markdown]
# 1.1 소환사 정보 가져오기

# %%
import requests

API_KEY = "RGAPI-578aae15-c434-444d-9b44-651b4265409a"
region = "asia"
game_name = "SummonerName"  # 소환사 이름
tag_line = "KR1"  # 소환사의 태그라인 (예: KR1)

# 소환사 정보 API URL
url = f"https://{region}.api.riotgames.com/riot/account/v1/accounts/by-riot-id/{game_name}/{tag_line}?api_key={API_KEY}"

# API 요청
response = requests.get(url)
if response.status_code == 200:
    data = response.json()
    print("PUUID:", data["puuid"])
else:
    print("Error:", response.status_code, response.json())
# Out:
# PUUID: PoG4YoqwlcVQWNazh27Gvx0F4Jr2wE39A_ztCuyOY0L6bDJ6X1kzRXrSE2gMCC2BsI0GHPND4kJpgg

# %% [markdown]
# 1.2 매치 히스토리 가져오기

# %%
puuid = "PoG4YoqwlcVQWNazh27Gvx0F4Jr2wE39A_ztCuyOY0L6bDJ6X1kzRXrSE2gMCC2BsI0GHPND4kJpgg"  # 위 코드로 얻은 PUUID
url = f"https://asia.api.riotgames.com/lol/match/v5/matches/by-puuid/{puuid}/ids?start=0&count=10&api_key={API_KEY}"

response = requests.get(url)
if response.status_code == 200:
    match_ids = response.json()
    print("Match IDs:", match_ids)
else:
    print("Error:", response.status_code, response.json())
# Out:
# Match IDs: ['KR_7381344933', 'KR_7381325195', 'KR_7381272549', 'KR_7381198564', 'KR_7381114715', 'KR_7381000163', 'KR_7380892805', 'KR_7380799726', 'KR_7380697566', 'KR_7380631650']

# %% [markdown]
# 1.3 매치 상세 데이터 가져오기

# %%
# 가져온 매치 ID 목록
match_ids = ['KR_7381344933', 'KR_7381325195', 'KR_7381272549', 'KR_7381198564', 'KR_7381114715', 'KR_7381000163', 'KR_7380892805', 'KR_7380799726', 'KR_7380697566', 'KR_7380631650']

# 각 매치 데이터를 저장할 리스트
all_match_data = []

for match_id in match_ids:
    url = f"https://asia.api.riotgames.com/lol/match/v5/matches/{match_id}?api_key={API_KEY}"
    response = requests.get(url)
    if response.status_code == 200:
        match_data = response.json()
        all_match_data.append(match_data)
        print(f"Collected data for match {match_id}")
    else:
        print(f"Error fetching match {match_id}: {response.status_code}")
# Out:
# Collected data for match KR_7381344933
# Collected data for match KR_7381325195
# Collected data for match KR_7381272549
# Collected data for match KR_7381198564
# Collected data for match KR_7381114715
# Collected data for match KR_7381000163
# Collected data for match KR_7380892805
# Collected data for match KR_7380799726
# Collected data for match KR_7380697566
# Collected data for match KR_7380631650

# %% [markdown]
# 1.4 데이터 정리

# %%
import pandas as pd

# 데이터를 정리하여 데이터프레임으로 변환
data = []
for match in all_match_data:
    for player in match['info']['participants']:
        data.append({
            "Summoner": player['summonerName'],
            "Win": player['win'],
            "Items": [player[f'item{i}'] for i in range(6)],
            "GameDuration": match['info']['gameDuration']
        })

df = pd.DataFrame(data)

# %% [markdown]
# 1.5 데이터 저장

# %%
df.to_csv("match_data.csv", index=False, encoding="utf-8-sig")
print("Data saved to match_data.csv")
# Out:
# Data saved to match_data.csv

# %% [markdown]
# # 2. 데이터 정규화 및 PCA(주성분 분석)

# %% [markdown]
# 3.1 데이터 정규화

# %%
from sklearn.preprocessing import MinMaxScaler

# 아이템 빈도수 계산 및 정규화
item_counts = df.explode("Items")["Items"].value_counts()
item_counts_df = item_counts.reset_index()
item_counts_df.columns = ["Item", "Count"]

scaler = MinMaxScaler()
item_counts_df["NormalizedCount"] = scaler.fit_transform(item_counts_df[["Count"]])

# %% [markdown]
# 3.2 PCA 수행

# %%
from sklearn.decomposition import PCA

# PCA를 위해 아이템 빈도수 데이터 준비
pca = PCA(n_components=1)
pca_result = pca.fit_transform(item_counts_df[["NormalizedCount"]])

item_counts_df["PCA1"] = pca_result[:, 0]

print(item_counts_df.head())
# Out:
#    Item  Count  NormalizedCount      PCA1
# 0     0     71         1.000000  0.951721
# 1  2055     28         0.385714  0.337435
# 2  3047     19         0.257143  0.208863
# 3  1055     19         0.257143  0.208863
# 4  3158     17         0.228571  0.180292

# %%
# 설명력 확인
explained_variance_ratio = pca.explained_variance_ratio_
print("PCA 설명력:", explained_variance_ratio)
# Out:
# PCA 설명력: [1.]

# %% [markdown]
# # 4. 데이터 분석 및 모델링

# %% [markdown]
# 4.1 기본 그래프 시각화

# %%
import matplotlib.pyplot as plt

# 상위 10개 데이터로 시각화
top_items = item_stats.sort_values("WinRate", ascending=False).head(10)

plt.figure(figsize=(10, 6))
plt.bar(top_items["Item"], top_items["WinRate"], alpha=0.7, label="WinRate (%)", color="orange")
plt.bar(top_items["Item"], top_items["Count"], alpha=0.5, label="Count", color="blue")
plt.title("Top 10 Items by WinRate and Count")
plt.xlabel("Item ID")
plt.ylabel("Value")
plt.legend()
plt.show()

# %% [markdown]
# 4.2 선형 회귀 분석

# %%
from sklearn.linear_model import LinearRegression

X = item_counts_df[["PCA1"]]
y = item_win_rate_df["WinRate"]

model = LinearRegression()
model.fit(X, y)

print("회귀 분석 결과:")
print("기울기:", model.coef_[0])
print("절편:", model.intercept_)

# %% [markdown]
# # 5. 결과 시각화

# %% [markdown]
# 5.1 PCA와 회귀 결과 시각화

# %%
import matplotlib.pyplot as plt

plt.scatter(item_counts_df["PCA1"], y, color='blue', label='Actual WinRate')
plt.plot(item_counts_df["PCA1"], model.predict(X), color='red', label='Regression Line')
plt.title("PCA 기반 선형 회귀 분석")
plt.xlabel("PCA1")
plt.ylabel("WinRate (%)")
plt.legend()
plt.show()

# %% [markdown]
# 5.2 아이템별 주요 통계 시각화

# %%
top_items = item_counts_df.sort_values("NormalizedCount", ascending=False).head(10)

plt.figure(figsize=(10, 6))
plt.bar(top_items["Item"], top_items["NormalizedCount"], color='blue', alpha=0.7, label="Normalized Count")
plt.bar(top_items["Item"], top_items["PCA1"], color='orange', alpha=0.7, label="PCA1")
plt.title("Top 10 Items by Count and PCA")
plt.xlabel("Item ID")
plt.ylabel("Value")
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
plt.bar(item_counts_df["Item"], item_counts_df["PCA1"], color='blue', alpha=0.7)
plt.title("PCA1 값을 기반으로 한 아이템 분석")
plt.xlabel("Item ID")
plt.ylabel("PCA1 Value")
plt.xticks(rotation=45)
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 44050 (\N{HANGUL SYLLABLE GABS}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 51012 (\N{HANGUL SYLLABLE EUL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 44592 (\N{HANGUL SYLLABLE GI}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 48152 (\N{HANGUL SYLLABLE BAN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 51004 (\N{HANGUL SYLLABLE EU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 47196 (\N{HANGUL SYLLABLE RO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 54620 (\N{HANGUL SYLLABLE HAN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 48516 (\N{HANGUL SYLLABLE BUN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49437 (\N{HANGUL SYLLABLE SEOG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# 승률 데이터와 결합
merged_data = pd.merge(item_counts_df, item_win_rate_df, on="Item")

# PCA1과 승률 간의 관계 확인
plt.scatter(merged_data["PCA1"], merged_data["WinRate"], color='green', alpha=0.5)
plt.title("PCA1과 아이템 승률의 관계")
plt.xlabel("PCA1")
plt.ylabel("WinRate (%)")
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 44284 (\N{HANGUL SYLLABLE GWA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 50500 (\N{HANGUL SYLLABLE A}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 51060 (\N{HANGUL SYLLABLE I}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 53596 (\N{HANGUL SYLLABLE TEM}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49849 (\N{HANGUL SYLLABLE SEUNG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 47456 (\N{HANGUL SYLLABLE RYUL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 51032 (\N{HANGUL SYLLABLE YI}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 44288 (\N{HANGUL SYLLABLE GWAN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 44228 (\N{HANGUL SYLLABLE GYE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
